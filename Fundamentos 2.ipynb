# %%
print("Hola Jovenes")
# Out:
# Hola Jovenes

# %%
x=input("Dame el primer numero ")
y=input("Dame el segundo numero ")
x1=int(x)
y1=int(y)
z=x1+y1
print("El resultado de",x1 ,"mas",y1, "es igual a:",z )
# Out:
# Dame el primer numero 2
# Dame el segundo numero 3
# El resultado de 2 mas 3 es igual a: 5

# %%
x=int(input("Dame el primer numero "))
y=int(input("Dame el segundo numero "))
print("El resultado de {} x {} es igual a {}".format )
# Out:
# Dame el primer numero 2
# Dame el segundo numero 3
# El resultado de 2 mas 3 es igual a: 5

# %%
var="Miguel"
if var=="Daniel":
  print("eres Daniel")
elif var=="Daniel":
  print("no eres Daniel")
else
  print("No eres Daniel ni Miguel")
# Out:
#   File "<ipython-input-35-2c29a86b7700>", line 6
#     else
#         ^
# SyntaxError: invalid syntax

# %%
from os import register_at_fork
print("Esto es una Calculadora")
print("Elije el tipo de opcion del menu")
print("1. Sumar")
print("2. Restar")
print("3. Multiplicar")
print("4. Dividir")
res=input("¿Que es lo que quieres hacer? ")
x=float(input("Escribe el Primer numero: "))
y=float(input("Escribe el Segundo numero: "))
if res=="Sumar":
  print("{} + {} = {}".format(x,y, x+y))
  pass
elif res=="Restar":
  print("{} + {} = {}".format(x,y, x-y))
elif res=="Multiplicar":
  print("{} + {} = {}".format(x,y, x*y))
else:
  print("{} + {} = {}".format(x,y, x/y))
# Out:
# Esto es una Calculadora
# Elije el tipo de opcion del menu
# 1. Sumar
# 2. Restar
# 3. Multiplicar
# 4. Dividir
# ¿Que es lo que quieres hacer? 4
# Escribe el Primer numero: 6
# Escribe el Segundo numero: 2
# 6.0 + 2.0 = 3.0

# %%
num1=10
num2=3
if num1==num2:
  print("Son iguales")
elif num1>num2:
  print("El primer numero es mayor")
elif num1<num2:
  print("El segundo numero es mayor")
# Out:
# El primer numero es mayor

# %%
num1=10
num2=3
if num1!=num2:
  print("Son diferentes")
else:
  print("son iguales")
# Out:
# Son diferentes

# %%
usuario_db="Miguel"
contraseña_db="qwerty"
print("Login")
usuario_ingresado=input("Nombre de usuario: ")
contraseña_ingresada=input("Contraseña: ")
if usuario_ingresado==usuario_db:
  print("Usuario encontrado")
  if contraseña_ingresada==contraseña_db:
    print("La contraseña coincide")
    print("Bienvenido al Sistema")
  else:
    print("La contraseña no caoincide")
else:
  print("Usuario no Encontrado")
# Out:
# Login
# Nombre de usuario: Miguel
# Contraseña: qwerty
# Usuario encontrado
# La contraseña coincide
# Bienvenido al Sistema
