# %%
# 1+2+3+4+5....+98+99+100=..?
#for

# %%
for i in range(10):
  print("el valor de i es?", i)
#la i es variable y el 10 es las veces que se mostrará
#aqui en el ejemplo solo se aumenta en 1 en cada interaccion

# %%
suma=0 #la suma empieza en 0
for i in range (100):
  suma=suma+(i+1) 
#print(i+1) le sumo 1 para que empieze desde 1 y no 0
print(suma)
#suma=1, i=1, i+1=1
# Out:
# 5050

# %%
for i in range(1,21,2): #como se observa en la linea de codigo es un rango Inicio/Final, el final no lo toca.
#el tercer numero es el incremento.
 print(i)

# %%
suma=0
for i in range (100,201):
  suma=suma+(i+1) 
print(suma)

# %%
#Programa donde le pidan al usuario el limite superior
#para realizar la suma aprtiendo desde 0 hasta llegar al limite superior
#si el usuario me dice que el limite superior es 145
#suma de 1+2+3+4+5+6......+145
limite=int(input("Dame el limite superior:"))
suma=0
for suma in range (0,limite):
 print("la suma es:", suma)

# %%
#Programa donde le pidan al usuario el limite superior
#para realizar la suma aprtiendo desde 0 hasta llegar al limite superior
#si el usuario me dice que el limite superior es 145
#suma de 1+2+3+4+5+6......+145
limite=int(input("Dame el limite superior:"))
suma=0
for i in range(1,limite+1):
  suma+i #suma=suma+i
  print("la suma es:", suma)

# %%
9//4 #dos diagonales te entrega la parte entera de la division
9%5 # % este operador entrega lo que falta, (Residuo) de la división
# Out:
# 2

# %%
#este preograma suma numeros pares
# en un rango desde 1 hasta el que nos diga el usuario
#2+4+6+8+10.... limite superior
limite=int(input("Dame el limite superior:"))
suma=0
for i in range(1,limite+1):
  if i%2==0:
   suma+=i #suma=suma+i
  print("la suma es:", suma)
# Out:
# Dame el limite superior:10
# la suma es: 0
# la suma es: 2
# la suma es: 2
# la suma es: 6
# la suma es: 6
# la suma es: 12
# la suma es: 12
# la suma es: 20
# la suma es: 20
# la suma es: 30
